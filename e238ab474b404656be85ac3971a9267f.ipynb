# %% [markdown]
# <img
# src="attachment:vertopal_e238ab474b404656be85ac3971a9267f/media/image1.png"
# style="width:4.62917in;height:3.27639in" /><img
# src="attachment:vertopal_e238ab474b404656be85ac3971a9267f/media/image2.png"
# style="width:9.59722in;height:0.22222in" /><img
# src="attachment:vertopal_e238ab474b404656be85ac3971a9267f/media/image3.png"
# style="width:10.11111in;height:0.26389in" /><img
# src="attachment:vertopal_e238ab474b404656be85ac3971a9267f/media/image4.png"
# style="width:10.05556in;height:5.23611in" /><img
# src="attachment:vertopal_e238ab474b404656be85ac3971a9267f/media/image5.png"
# style="width:11.33333in;height:1.86111in" />
#
# > MyTop100Movies - API, Database, CRUD - Application which lets users
# > set their top 100 movies. Movies could come from an API like The Movie
# > Database ( http://tmdb.org ). Should allow users to add a movie, list
# > and rank their movie selections. Start with basic CRUD for movies and
# > add features.
# >
# > Test Criteria
# > \` Design your schema properly for Nosql or proper relationships for
# > SQL database implementatioR \` Write a unit test for all services and
# > controllerL
# > \` Use express.js but nest.js would be a pluL
# > \` Document your API using postman or swaggeI
# > \` Host it on a live link when done, push the code to Github.
# >
# > Timeline for completion: 48 hours, kindly let us know if you come up
# > with any challenges or need a deadline extension. Final work should be
# > submitted to careers@montech.io
# >
# > For More Information
#
# <table>
# <colgroup>
# <col style="width: 33%" />
# <col style="width: 33%" />
# <col style="width: 33%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th></th>
# <th></th>
# <th><blockquote>
# <p>+1 301 549 0179.</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
